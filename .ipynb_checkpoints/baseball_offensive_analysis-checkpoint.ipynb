# %%
import pandas as pd

# %%
classic_stats = pd.read_csv('data/classic_stats.csv')
statcast = pd.read_csv('data/statcast.csv')

# %%
classic_stats
# Out:
#      last_name  first_name  year  player_age  b_ab  b_total_pa  b_total_hits  \
# 0      Beltran      Carlos  2017          40   467         509           108
# 1       Pujols      Albert  2017          37   593         636           143
# 2        Mauer         Joe  2017          34   525         597           160
# 3      Cabrera      Miguel  2017          34   469         529           117
# 4     Phillips     Brandon  2017          36   572         604           163
# ..         ...         ...   ...         ...   ...         ...           ...
# 845     Albies       Ozzie  2018          21   639         684           167
# 846    Chapman        Matt  2018          25   547         616           152
# 847    Hoskins        Rhys  2018          25   558         660           137
# 848  Schwarber        Kyle  2018          25   428         510           102
# 849    Moncada        Yoan  2018          23   578         650           136
#
# ...
